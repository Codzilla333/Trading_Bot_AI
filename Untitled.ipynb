# %%
import MetaTrader5 as mt
import pandas as pd
import plotly.express as px
from datetime import datetime

# %%
mt.initialize()
# Out:
# True

# %%
login = 122940720
password = "Demo@1234"
server = "Exness-MT5Trial7"

mt.login(login,password,server)
# Out:
# True

# %%
account_info = mt.account_info()

# %%
account_info
# Out:
# AccountInfo(login=122940720, trade_mode=0, leverage=2000, limit_orders=1024, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=50.0, credit=0.0, profit=0.0, equity=50.0, margin=0.0, margin_free=50.0, margin_level=0.0, margin_so_call=60.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Demo-account', server='Exness-MT5Trial7', currency='USD', company='Exness Technologies Ltd')

# %%
num_symbols = mt.symbols_total()
num_symbols
# Out:
# 395

# %%
symbols = mt.symbols_get()
symbols
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=0, trade_calc_mode=0, trade_mode=0, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.0, trade_tick_value_profit=0.0, trade_tick_value_loss=0.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1e-08, volume_max=1e-08, volume_step=1e-08, volume_limit=0.0,
# ...

# %%
XAU_info = mt.symbol_info("XAUUSDm")._asdict()
XAU_info
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1702310480,
#  'digits': 3,
#  'spread': 200,
#  'spread_float': True,
#  'ticks_bookdepth': 0,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 3,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1983.537,
#  'bidhigh': 2007.808,
#  'bidlow': 1980.572,
#  'ask': 1983.737,
#  'askhigh': 2008.008,
#  'asklow': 1980.772,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
# ...

# %%
print(XAU_info)
# Out:
# None

# %%
xau_price = mt.symbol_info_tick("XAUUSDm")._asdict()
xau_price
# Out:
# {'time': 1702315498,
#  'bid': 1978.532,
#  'ask': 1978.732,
#  'last': 0.0,
#  'volume': 0,
#  'time_msc': 1702315498541,
#  'flags': 6,
#  'volume_real': 0.0}

# %%
xau_price
# Out:
# {'time': 1702315488,
#  'bid': 1978.41,
#  'ask': 1978.61,
#  'last': 0.0,
#  'volume': 0,
#  'time_msc': 1702315488141,
#  'flags': 6,
#  'volume_real': 0.0}

# %%
ohlc_data = pd.DataFrame(mt.copy_rates_range("XAUUSDm",
                                             mt.TIMEFRAME_D1,
                                             datetime(2023,1,1),
                                            datetime.now()))
ohlc_data['datetime'] = pd.to_datetime(ohlc_data['time'],unit='s')
fig = px.line(ohlc_data,x='datetime',y='close', title='XAUUSD 2023',
             labels={'datetime':'Date','close':'Closing Price'})
                                             
fig.show()
# Out:
# <div>                            <div id="2898a849-50af-4559-9a78-ca2c3ac6b93d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2898a849-50af-4559-9a78-ca2c3ac6b93d")) {                    Plotly.newPlot(                        "2898a849-50af-4559-9a78-ca2c3ac6b93d",                        [{"hovertemplate":"Date=%{x}<br>Closing Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","202
# ...

# %%
ohlc_data
# Out:
#            time      open      high       low     close  tick_volume  spread  \
# 0    1672617600  1825.968  1830.460  1823.998  1829.131         2383     834
# 1    1672704000  1829.110  1849.902  1826.747  1836.522       123212     200
# 2    1672790400  1836.501  1865.086  1836.185  1854.827       124302     200
# 3    1672876800  1854.794  1858.971  1824.835  1832.799       116567     200
# 4    1672963200  1832.800  1869.783  1831.265  1865.989       119328     200
# ..          ...       ...       ...       ...       ...          ...     ...
# 289  1701820800  2018.904  2035.915  2018.683  2027.006       110332     199
# 290  1701907200  2026.977  2039.891  2020.091  2027.916       109396     199
# 291  1701993600  2028.061  2034.005  1994.518  2004.340       127419     199
# 292  1702166400  2005.584  2007.648  2004.547  2007.054         3143     199
# 293  1702252800  2006.993  2007.808  1976.059  1977.218        88592     199
#
#      real_volume   datetime
# ...

# %%
tick_data = pd.DataFrame(mt.copy_ticks_range("XAUUSD",
                                            datetime(2023,12,1),
                                            datetime.now(),
                                            mt.COPY_TICKS_ALL))
fig = px.line(tick_data,x=tick_data['time'],y=[tick_data['bid'],tick_data['ask']])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File E:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File E:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
tick_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []
